# %% [markdown]
# <a href="https://colab.research.google.com/github/tejvirmann/angularlist/blob/master/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hiroharu-kato/neural_renderer.git
# Out:
# Cloning into 'neural_renderer'...
# remote: Enumerating objects: 614, done.
# remote: Total 614 (delta 0), reused 0 (delta 0), pack-reused 614
# Receiving objects: 100% (614/614), 18.70 MiB | 37.10 MiB/s, done.
# Resolving deltas: 100% (353/353), done.

# %%
# !python3 --version
# Out:
# Python 3.7.10

# %%
# !python setup.py install --user
# Out:
# running install
# running bdist_egg
# running egg_info
# creating neural_renderer.egg-info
# writing neural_renderer.egg-info/PKG-INFO
# writing dependency_links to neural_renderer.egg-info/dependency_links.txt
# writing requirements to neural_renderer.egg-info/requires.txt
# writing top-level names to neural_renderer.egg-info/top_level.txt
# writing manifest file 'neural_renderer.egg-info/SOURCES.txt'
# writing manifest file 'neural_renderer.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/neural_renderer
# copying neural_renderer/get_points_from_angles.py -> build/lib/neural_renderer
# copying neural_renderer/save_obj.py -> build/lib/neural_renderer
# copying neural_renderer/__init__.py -> build/lib/neural_renderer
# copying neural_renderer/cross.py -> build/lib/neural_renderer
# copying neural_renderer/rasterize.py -> build/lib/neural_renderer
# ...

# %%
# !pip install --upgrade scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 103kB/s
# ...
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
# !bash ./examples/run.sh
# Out:
# Traceback (most recent call last):
#   File "examples/example1.py", line 14, in <module>
#     import neural_renderer
# ModuleNotFoundError: No module named 'neural_renderer'
# Traceback (most recent call last):
#   File "examples/example2.py", line 15, in <module>
#     import neural_renderer
# ModuleNotFoundError: No module named 'neural_renderer'
# Traceback (most recent call last):
#   File "examples/example3.py", line 15, in <module>
#     import neural_renderer
# ModuleNotFoundError: No module named 'neural_renderer'
# Traceback (most recent call last):
#   File "examples/example4.py", line 15, in <module>
#     import neural_renderer
# ModuleNotFoundError: No module named 'neural_renderer'

# %%
pwd
# Out:
# '/content'

# %%
cd neural_renderer/
# Out:
# /content/neural_renderer
